# %%
import imageio

import matplotlib.pyplot as plt

# %%
# image 1
im_1_image=imageio.imread("Mini_BAGLS_dataset/0.png")

# im_1_meta=imageio.imread("Mini_BAGLS_dataset/0.meta")
# plt.imshow(im_1_meta)
import json

with open("Mini_BAGLS_dataset/0.meta", "r") as file:
    data = json.load(file)
    print(data)

im_1_seg=imageio.imread("Mini_BAGLS_dataset/0_seg.png")

# showing images
fig, axes = plt.subplots(1, 2, figsize=(6, 4))
axes[0].imshow(im_1_image)
axes[0].set_title("Original Image")
axes[0].axis('off')

axes[1].imshow(im_1_seg)
axes[1].set_title("Segmented Image")
axes[1].axis('off')

plt.tight_layout()
plt.show()
# Out:
# {'Video Id': 37, 'Camera': 'KayPentax HSV 9710 (Photron)', 'Sampling rate (Hz)': 4000, 'Video resolution (px, HxW)': [512, 256], 'Color': False, 'Endoscope orientation': '70°', 'Endoscope application': 'oral', 'Age range (yrs)': '20-30', 'Subject sex': 'w', 'Subject disorder status': 'healthy', 'Segmenter': 0, 'Post-processed': 1}
# C:\Users\Binish\AppData\Local\Temp\ipykernel_19556\3119194198.py:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   im_1_image=imageio.imread("Mini_BAGLS_dataset/0.png")
# ...

# %%
# image 2
im_2_image=imageio.imread("Mini_BAGLS_dataset/1.png")

# im_2_meta=imageio.imread("Mini_BAGLS_dataset/1.meta")
# plt.imshow(im_2_meta)
import json

with open("Mini_BAGLS_dataset/1.meta", "r") as file:
    data = json.load(file)
    print(data)

im_2_seg=imageio.imread("Mini_BAGLS_dataset/1_seg.png")

# showing images
fig, axes = plt.subplots(1, 2, figsize=(6, 4))
axes[0].imshow(im_2_image)
axes[0].set_title("Original Image")
axes[0].axis('off')

axes[1].imshow(im_2_seg)
axes[1].set_title("Segmented Image")
axes[1].axis('off')

plt.tight_layout()
plt.show()
# Out:
# {'Video Id': 277, 'Camera': 'KayPentax HSV 9710 (Photron)', 'Sampling rate (Hz)': 4000, 'Video resolution (px, HxW)': [512, 256], 'Color': False, 'Endoscope orientation': '70°', 'Endoscope application': 'oral', 'Age range (yrs)': '', 'Subject sex': 'w', 'Subject disorder status': 'healthy', 'Segmenter': 0, 'Post-processed': 1}
# C:\Users\Binish\AppData\Local\Temp\ipykernel_19556\2018637758.py:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   im_2_image=imageio.imread("Mini_BAGLS_dataset/1.png")
# ...

# %%
# image 3
im_3_image=imageio.imread("Mini_BAGLS_dataset/2.png")


import json

with open("Mini_BAGLS_dataset/2.meta", "r") as file:
    data = json.load(file)
    print(data)

im_3_seg=imageio.imread("Mini_BAGLS_dataset/2_seg.png")

# showing images
fig, axes = plt.subplots(1, 2, figsize=(6, 4))
axes[0].imshow(im_3_image)
axes[0].set_title("Original Image")
axes[0].axis('off')

axes[1].imshow(im_3_seg)
axes[1].set_title("Segmented Image")
axes[1].axis('off')

plt.tight_layout()
plt.show()
# Out:
# {'Video Id': 313, 'Camera': 'KayPentax HSV 9710 (Photron)', 'Sampling rate (Hz)': 4000, 'Video resolution (px, HxW)': [512, 256], 'Color': False, 'Endoscope orientation': '70°', 'Endoscope application': 'oral', 'Age range (yrs)': '20-30', 'Subject sex': 'w', 'Subject disorder status': 'healthy', 'Segmenter': 0, 'Post-processed': 2}
# C:\Users\Binish\AppData\Local\Temp\ipykernel_19556\3695889638.py:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   im_3_image=imageio.imread("Mini_BAGLS_dataset/2.png")
# ...

# %%
# image 4
im_4_image=imageio.imread("Mini_BAGLS_dataset/3.png")


import json

with open("Mini_BAGLS_dataset/3.meta", "r") as file:
    data = json.load(file)
    print(data)

im_4_seg=imageio.imread("Mini_BAGLS_dataset/3_seg.png")

# showing images
fig, axes = plt.subplots(1, 2, figsize=(6, 4))
axes[0].imshow(im_4_image)
axes[0].set_title("Original Image")
axes[0].axis('off')

axes[1].imshow(im_4_seg)
axes[1].set_title("Segmented Image")
axes[1].axis('off')

plt.tight_layout()
plt.show()
# Out:
# {'Video Id': 527, 'Camera': 'KayPentax HSV 9710 (Photron)', 'Sampling rate (Hz)': 4000, 'Video resolution (px, HxW)': [512, 256], 'Color': False, 'Endoscope orientation': '70°', 'Endoscope application': 'oral', 'Age range (yrs)': '60-70', 'Subject sex': 'w', 'Subject disorder status': 'healthy', 'Segmenter': 0, 'Post-processed': 1}
# C:\Users\Binish\AppData\Local\Temp\ipykernel_19556\574525751.py:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   im_4_image=imageio.imread("Mini_BAGLS_dataset/3.png")
# ...
